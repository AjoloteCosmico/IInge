# %%
import pandas as pd
import sys
import mysql.connector
import os
from dotenv import load_dotenv
load_dotenv()

#configurar la conexion a la base de datos
DB_USERNAME = os.getenv('DB_USERNAME')
DB_DATABASE = os.getenv('DB_DATABASE')
DB_PASSWORD = os.getenv('DB_PASSWORD')
DB_PORT = os.getenv('DB_PORT')

# %%
DB_DATABASE
# Out:
# 'laravel'

# %%
cnx = mysql.connector.connect(user=DB_USERNAME,
                              password=DB_PASSWORD,
                              host='localhost',
                              port=DB_PORT,
                              database=DB_DATABASE,
                              use_pure=False)
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File c:\Users\fgonzalez\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py:263, in CMySQLConnection._open_connection(self)
#     262 try:
# --> 263     self._cmysql.connect(**cnx_kwargs)
#     264     self._cmysql.converter_str_fallback = self._converter_str_fallback
#
# MySQLInterfaceError: Unknown database 'laravel'
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In [17], line 13
#      10 DB_PASSWORD = os.getenv('DB_PASSWORD')
#      11 DB_PORT = os.getenv('DB_PORT')
# ---> 13 cnx = mysql.connector.connect(user=DB_USERNAME,
#      14                               password=DB_PASSWORD,
#      15                               host='localhost',
# ...

# %%
file=pd.ExcelFile("BIOSOL oficial 1.xlsx")

# %%
file.sheet_names
# Out:
# ['Datos Entrada',
#  'Temp',
#  'HR',
#  'Tn',
#  'Olgyay',
#  'Olgyay datos',
#  'Isorreq',
#  'Control Solar 1er Sem',
#  'CS 1er sem datos',
#  'CS 1er sem datos (2)',
#  'Control Solar 2do Sem',
#  'CS 2do sem datos',
#  'Eficiencia Alero',
#  'Eficiencia Partesol',
#  'Irradiancia Horizontal',
#  'Irradiancia Sup Inclinadas',
#  'Cálculos irradiancia',
#  'Cálculos iluminancia',
#  'Eficacia Luminosa',
#  'Iluminancia Horizontal',
#  'Iluminancia Sup Inclinadas']

# %%
il_parameters=pd.read_excel("BIOSOL oficial 1.xlsx",sheet_name='Cálculos iluminancia', skiprows = 13, nrows=1,  usecols= 'F:O').fillna(0)
# Out:
# c:\Users\fgonzalez\AppData\Local\Programs\Python\Python310\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
il_parameters
# Out:
#    Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  \
# 0          21  -20.138015       29.08    0.344284         211     0.975327
#
#    Unnamed: 11  Unnamed: 12  Unnamed: 13  Unnamed: 14
# 0  1433.268875            0           90          0.0

# %%
il=pd.read_excel("BIOSOL oficial 1.xlsx",sheet_name='Cálculos iluminancia', skiprows = 15, nrows=25,  usecols= 'E:BI').fillna(0).iloc[1: , :]
# Out:
# c:\Users\fgonzalez\AppData\Local\Programs\Python\Python310\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
len(il.columns)
# Out:
# 57

# %%
il
# Out:
#                    hora  Unnamed: 5  Unnamed: 6  Unnamed: 7        Z[°]  \
# 1              01:00:00       165.0  -73.716869   60.072271  163.716869
# 2              02:00:00       150.0  -61.392242   78.641635  151.392242
# 3              03:00:00       135.0  -48.376277   88.120784  138.376277
# 4              04:00:00       120.0  -35.281146   95.111099  125.281146
# 5              05:00:00       105.0  -22.314890  101.395227  112.314890
# 6              06:00:00        90.0   -9.632722  107.769355   99.632722
# 7              07:00:00        75.0    2.581069  114.797483   87.418931
# 8              08:00:00        60.0   14.059262  123.050540   75.940738
# 9              09:00:00        45.0   24.384588  133.205721   65.615412
# 10             10:00:00        30.0   32.905461  146.003910   57.094539
# 11             11:00:00        15.0   38.698646  161.859022   51.301354
# 12             12:00:00         0.0   40.781985  180.000000   49.218015
# ...

# %%
#Crear query para tablas 
for i in range(56):
    print("ALTER TABLE `iluminancia_mediciones` ADD `a"+str(i+2)+"` FLOAT NOT NULL AFTER `a1`;")
# Out:
# ALTER TABLE `iluminancia_mediciones` ADD `a2` FLOAT NOT NULL AFTER `a1`;
# ALTER TABLE `iluminancia_mediciones` ADD `a3` FLOAT NOT NULL AFTER `a1`;
# ALTER TABLE `iluminancia_mediciones` ADD `a4` FLOAT NOT NULL AFTER `a1`;
# ALTER TABLE `iluminancia_mediciones` ADD `a5` FLOAT NOT NULL AFTER `a1`;
# ALTER TABLE `iluminancia_mediciones` ADD `a6` FLOAT NOT NULL AFTER `a1`;
# ALTER TABLE `iluminancia_mediciones` ADD `a7` FLOAT NOT NULL AFTER `a1`;
# ALTER TABLE `iluminancia_mediciones` ADD `a8` FLOAT NOT NULL AFTER `a1`;
# ALTER TABLE `iluminancia_mediciones` ADD `a9` FLOAT NOT NULL AFTER `a1`;
# ALTER TABLE `iluminancia_mediciones` ADD `a10` FLOAT NOT NULL AFTER `a1`;
# ALTER TABLE `iluminancia_mediciones` ADD `a11` FLOAT NOT NULL AFTER `a1`;
# ALTER TABLE `iluminancia_mediciones` ADD `a12` FLOAT NOT NULL AFTER `a1`;
# ALTER TABLE `iluminancia_mediciones` ADD `a13` FLOAT NOT NULL AFTER `a1`;
# ALTER TABLE `iluminancia_mediciones` ADD `a14` FLOAT NOT NULL AFTER `a1`;
# ...
